# %%
#Add two numbers

a = int(input("Give me number one \n"))
b = int(input("Give me number two \n"))

print ("Output is \n",a + b)
# Out:
# Give me number one
#  5
# Give me number two
#  7
# Output is
#  12
